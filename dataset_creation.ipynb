# %%
import matplotlib.pyplot as plt
import pandas as pd
import parquet
import pyarrow

# %%
dataset = pd.read_parquet("lumen_dataset/train.parquet")
dataset.head()
# Out:
#    reservation_id  night_number  stay_date  guest_id guest_country_id  \
# 0           73710           1.0 2007-12-13     22897               HR
# 1           73710           2.0 2007-12-14     22897               HR
# 2           74464           1.0 2008-01-01    106278               HR
# 3           74461           1.0 2008-01-01     38936               GB
# 4           74466           1.0 2008-01-01    106279               HR
#
#   reservation_status reservation_date   date_from     date_to  resort_id  ...  \
# 0        Checked-out       2007-11-28  2007-12-13  2007-12-15          1  ...
# 1        Checked-out       2007-11-28  2007-12-13  2007-12-15          1  ...
# 2        Checked-out       2007-12-29  2008-01-01  2008-01-02          1  ...
# 3          Cancelled       2007-12-29  2008-01-01  2008-01-02          1  ...
# 4          Cancelled       2007-12-29  2008-01-01  2008-01-03          1  ...
#
#       price  price_tax  total_price_tax  total_price  food_price  \
# 0  4255.462    425.517          452.089     4564.690     265.428
# 1  4243.709    424.349          450.921     4552.937     265.428
# 2  4336.857    433.693         3806.147    19764.823     530.929
# 3  8536.766    853.662         1012.948    10392.280    1592.714
# 4       NaN        NaN              NaN          NaN         NaN
#
#    food_price_tax  other_price  other_price_tax  room_category_id  \
# 0          26.572       43.800            0.000                 3
# 1          26.572       43.800            0.000                 3
# 2          53.071    14897.037         3319.383                 4
# 3         159.286      262.800            0.000                 5
# 4             NaN          NaN              NaN                 6
#
#    sales_channel_id
# 0              10.0
# 1              10.0
# 2               4.0
# 3               3.0
# 4               4.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Filtering out cancelled reservations

# %%
dataset_without_cancelled = dataset[dataset["reservation_status"] != "Cancelled"]

# %%
dataset_without_cancelled.head()
# Out:
#    reservation_id  night_number  stay_date  guest_id guest_country_id  \
# 0           73710           1.0 2007-12-13     22897               HR
# 1           73710           2.0 2007-12-14     22897               HR
# 2           74464           1.0 2008-01-01    106278               HR
# 6           74470           1.0 2008-01-01     38936               GB
# 7           74460           1.0 2008-01-01     38936               GB
#
#   reservation_status reservation_date   date_from     date_to  resort_id  ...  \
# 0        Checked-out       2007-11-28  2007-12-13  2007-12-15          1  ...
# 1        Checked-out       2007-11-28  2007-12-13  2007-12-15          1  ...
# 2        Checked-out       2007-12-29  2008-01-01  2008-01-02          1  ...
# 6        Checked-out       2007-12-29  2008-01-01  2008-01-02          1  ...
# 7        Checked-out       2007-12-29  2008-01-01  2008-01-02          1  ...
#
#       price  price_tax  total_price_tax  total_price  food_price  \
# 0  4255.462    425.517          452.089     4564.690     265.428
# 1  4243.709    424.349          450.921     4552.937     265.428
# 2  4336.857    433.693         3806.147    19764.823     530.929
# 6  8536.766    853.662         1012.948    10392.280    1592.714
# 7  8536.766    853.662         1012.948    10392.280    1592.714
#
#    food_price_tax  other_price  other_price_tax  room_category_id  \
# 0          26.572       43.800            0.000                 3
# 1          26.572       43.800            0.000                 3
# 2          53.071    14897.037         3319.383                 4
# 6         159.286      262.800            0.000                 4
# 7         159.286      262.800            0.000                 5
#
#    sales_channel_id
# 0              10.0
# 1              10.0
# 2               4.0
# 6               3.0
# 7               3.0
#
# [5 rows x 24 columns]

# %%
dataset_without_cancelled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25596 entries, 0 to 31633
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   reservation_id      25596 non-null  int64
#  1   night_number        25596 non-null  float64
#  2   stay_date           25596 non-null  datetime64[ns]
#  3   guest_id            25596 non-null  int64
#  4   guest_country_id    25596 non-null  object
#  5   reservation_status  25596 non-null  object
#  6   reservation_date    25596 non-null  object
#  7   date_from           25596 non-null  object
#  8   date_to             25596 non-null  object
#  9   resort_id           25596 non-null  int64
#  10  cancel_date         113 non-null    object
#  11  room_cnt            25596 non-null  int64
#  12  adult_cnt           25596 non-null  int64
#  13  children_cnt        25596 non-null  int64
#  14  price               25444 non-null  float64
#  15  price_tax           25444 non-null  float64
#  16  total_price_tax     25562 non-null  float64
#  17  total_price         25562 non-null  float64
#  18  food_price          25444 non-null  float64
#  19  food_price_tax      25444 non-null  float64
#  20  other_price         25444 non-null  float64
#  21  other_price_tax     25444 non-null  float64
#  22  room_category_id    25596 non-null  int64
#  23  sales_channel_id    25596 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(7), object(6)
# memory usage: 4.9+ MB

# %% [markdown]
# ## Price Estimation

# %% [markdown]
# ### Price Calculation
# - There is ~200 rows where we know the individual prices but total price isn't calculated. So here we do that :)
# - But after dropping the cancelled values we determined it was actually 0 rows :)

# %%
count_missing_total_price = dataset_without_cancelled[
    dataset_without_cancelled['total_price'].isna() & 
    dataset_without_cancelled['price'].notna() & 
    dataset_without_cancelled['food_price'].notna() & 
    dataset_without_cancelled['other_price'].notna()
].shape[0]

count_missing_total_price
# Out:
# 0

# %%
mask = dataset_without_cancelled['total_price'].isna() & (dataset['food_price'].notna() | dataset['other_price'].notna())

dataset_without_cancelled.loc[mask, 'total_price'] = (
    dataset_without_cancelled.loc[mask, 'price'].fillna(0) + 
    dataset_without_cancelled.loc[mask, 'food_price'].fillna(0) + 
    dataset_without_cancelled.loc[mask, 'other_price'].fillna(0)
)

# %% [markdown]
# ### Estimating Missing Prices

# %%
missing_prices_count = len(dataset_without_cancelled[dataset_without_cancelled['price'].isnull()])
missing_prices_count
# Out:
# 152

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_parquet("../../lumen_dataset/train.parquet")
dataset.head()
# Out:
#    hotel_id datum_dolaska datum_kreiranja_rezervacije datum_odjave  \
# 0         0    2015-07-01                  2015-01-21   2015-07-01
# 1         0    2015-07-01                  2015-06-10   2015-07-01
# 2         0    2015-07-01                  2015-05-13   2015-07-02
# 3         0    2015-07-01                  2014-05-30   2015-07-02
# 4         0    2015-07-01                  2014-07-06   2015-07-03
#
#   datum_otkazivanja_rezervacije  broj_odraslih_gostiju  broj_djece_gostiju  \
# 0                          None                      2                 0.0
# 1                          None                      2                 0.0
# 2                          None                      1                 0.0
# 3                          None                      1                 0.0
# 4                          None                      2                 0.0
#
#   zemlja_gosta  kanal_prodaje_id  tip_sobe_id  cijena_nocenja  \
# 0          PRT                 0            0      100.000000
# 1          PRT                 0            0      100.000000
# 2          GBR                 0            1       64.991345
# 3          GBR                 1            1       74.368897
# 4          GBR                 2            1      130.973278
#
#   status_rezervacije  rezervacija_id  gost_id
# 0          Check-Out         1313223  1077152
# 1          Check-Out         1313224  1017906
# 2          Check-Out         1313225  1039896
# 3          Check-Out         1313226  1008245
# 4          Check-Out         1313227  1093703

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119210 entries, 0 to 119209
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   hotel_id                       119210 non-null  int32
#  1   datum_dolaska                  119210 non-null  datetime64[ns]
#  2   datum_kreiranja_rezervacije    119210 non-null  datetime64[ns]
#  3   datum_odjave                   119210 non-null  datetime64[ns]
#  4   datum_otkazivanja_rezervacije  44199 non-null   object
#  5   broj_odraslih_gostiju          119210 non-null  int64
#  6   broj_djece_gostiju             119210 non-null  float64
#  7   zemlja_gosta                   119210 non-null  object
#  8   kanal_prodaje_id               119210 non-null  int32
#  9   tip_sobe_id                    119210 non-null  int32
#  10  cijena_nocenja                 119210 non-null  float64
#  11  status_rezervacije             119210 non-null  object
#  12  rezervacija_id                 119210 non-null  int32
#  13  gost_id                        119210 non-null  int32
# dtypes: datetime64[ns](3), float64(2), int32(5), int64(1), object(3)
# memory usage: 10.5+ MB

# %% [markdown]
# # Detaljan pregled dolazaka po mesecima

# %%
dataset["datum_dolaska"] = pd.to_datetime(dataset["datum_dolaska"])
dataset["arrival_month"] = dataset["datum_dolaska"].dt.month
dataset["arrival_year"] = dataset["datum_dolaska"].dt.year
monthly_arrivals = dataset.groupby("arrival_month").size()

# %% [markdown]
# ## Pregled dolazaka po mesecima za sve hotele i sve godine

# %%
plt.figure(figsize=(10, 6))  # Optional: Adjusts the figure size
plt.bar(monthly_arrivals.index, monthly_arrivals.values, color="skyblue")
plt.xlabel("Month")
plt.ylabel("Number of Arrivals")
plt.title("Number of Arrivals per Month")
plt.xticks(
    monthly_arrivals.index,
    [
        "Jan",
        "Feb",
        "Mar",
        "Apr",
        "May",
        "Jun",
        "Jul",
        "Aug",
        "Sep",
        "Oct",
        "Nov",
        "Dec",
    ],
)
plt.show()

# %% [markdown]
# ## Prikaz broja dolazaka po hotelu i po godini
#
# - Dolasci u mesecu su izrazeni u procentu od ukupnog broja dolazaka u godini. Ovo je uradjeno s razlogom sto hotel 0 i hotel 1 nemaju ni blizu isti broj ukupnih dolazaka

# %%
arrival_count = (
    dataset.groupby(["hotel_id", "arrival_year", "arrival_month"])
    .size()
    .unstack(fill_value=0)
)

arrivals_percentage = (
    arrival_count.div(arrival_count.sum(axis=1), axis=0).fillna(0) * 100
)

unique_years = sorted(dataset["arrival_year"].unique())
unique_hotels = sorted(dataset["hotel_id"].unique())
num_years = len(unique_years)
num_hotels = len(unique_hotels)

# %%
fig, axs = plt.subplots(
    num_years,
    num_hotels,
    figsize=(5 * num_hotels, 5 * num_years),
    sharex="col",
    sharey="row",
)

for i, year in enumerate(unique_years):
    for j, hotel_id in enumerate(unique_hotels):
        if num_years == 1 or num_hotels == 1:
            ax = axs[max(i, j)]
        else:
            ax = axs[i, j]

        data = arrivals_percentage.xs(
            (hotel_id, year), level=("hotel_id", "arrival_year")
        ).T

        ax.bar(data.index, data.values.flatten(), color="skyblue")
        ax.set_title(f"Hotel {hotel_id}, {year}")
        ax.set_xticks(range(1, 13))
        ax.set_xticklabels(
            [
                "Jan",
                "Feb",
                "Mar",
                "Apr",
                "May",
                "Jun",
                "Jul",
                "Aug",
                "Sep",
                "Oct",
                "Nov",
                "Dec",
            ]
        )
        if j == 0:
            ax.set_ylabel("Percentage of Arrivals (%)")

plt.tight_layout()
plt.show()

# %% [markdown]
# Posto najvise ljudi dolazi u decembru, verovatno je u pitanju Zagreb zbog adventa

# %% [markdown]
# ## Provera anomalija

# %%
print(arrival_count)
# Out:
# arrival_month            1     2     3     4     5     6     7     8     9   \
# hotel_id arrival_year
# 0        2015             0     0     0     0     0     0  1378  1409  1585
#          2016           884  1519  1778  1867  1802  1369  1441  1685  1523
#          2017          1307  1583  1556  1742  1757  1675  1754  1800     0
# 1        2015           187     0     0     0  1075     0   768  1392  3524
#          2016          3110  2365  1057  1227  1983  3403  2848  2486  3868
#          2017          3979  2585  1164  1317  1516  3530  3351  2456     0
#
# arrival_month            10    11    12
# hotel_id arrival_year
# 0        2015          1569  1104  1264
#          2016          1984  1331  1381
#          2017             0     0     0
# 1        2015          2196  1759  2757
#          2016          4272  4274  7166
#          2017          2324  1515  3709

# %% [markdown]
# Prvo cemo pregledati u kojim mesecima se desilo da je broj dolazaka manji od 1% ukupnog broja dolazaka za tu godinu. Logika je da to ukazuje na neku gresku/anomaliju

# %%
print(arrivals_percentage)
# Out:
# arrival_month                 1          2          3          4          5   \
# hotel_id arrival_year
# 0        2015           0.000000   0.000000   0.000000   0.000000   0.000000
#          2016           4.761905   8.182504   9.577677  10.057100   9.706960
#          2017           9.921057  12.016092  11.811143  13.223015  13.336876
# 1        2015           1.369161   0.000000   0.000000   0.000000   7.870845
#          2016           8.171523   6.214036   2.777267   3.223942   5.210331
#          2017          14.497559   9.418494   4.241055   4.798513   5.523574
#
# arrival_month                 6          7          8          9          10  \
# hotel_id arrival_year
# 0        2015           0.000000  16.584427  16.957516  19.075701  18.883139
#          2016           7.374488   7.762336   9.076708   8.204051  10.687352
#          2017          12.714438  13.314104  13.663276   0.000000   0.000000
# 1        2015           0.000000   5.623078  10.191829  25.801728  16.078489
#          2016           8.941380   7.483118   6.531964  10.163168  11.224677
#          2017          12.861619  12.209429   8.948481   0.000000   8.467536
#
# arrival_month                 11         12
# hotel_id arrival_year
# 0        2015          13.286797  15.212420
#          2016           7.169791   7.439129
#          2017           0.000000   0.000000
# 1        2015          12.878899  20.185972
#          2016          11.229932  18.828661
#          2017           5.519930  13.513809

# %%
anomalie_months = []

for (hotel_id, year), row in arrivals_percentage.iterrows():
    for month, percentage in row.items():
        if percentage < 1:
            anomalie_months.append((hotel_id, year, month, percentage))

anomalie_months_df = pd.DataFrame(
    anomalie_months, columns=["Hotel ID", "Year", "Month", "Percentage"]
)

# %%
print(anomalie_months_df)
# Out:
#     Hotel ID  Year  Month  Percentage
# 0          0  2015      1         0.0
# 1          0  2015      2         0.0
# 2          0  2015      3         0.0
# 3          0  2015      4         0.0
# 4          0  2015      5         0.0
# 5          0  2015      6         0.0
# 6          0  2017      9         0.0
# 7          0  2017     10         0.0
# 8          0  2017     11         0.0
# 9          0  2017     12         0.0
# 10         1  2015      2         0.0
# 11         1  2015      3         0.0
# 12         1  2015      4         0.0
# 13         1  2015      6         0.0
# 14         1  2017      9         0.0

# %% [markdown]
# Mozemo videti da postoje meseci gde se desilo 0% dolazaka, sto verovatno znaci da se tu nisu ni pratili dolasci. Ovo treba nekako kompenzovati. Ideja je da meseci za koje nemamo podatke o dolascima uzmu kao vrednost, prosek dolazaka tog meseca u drugim godinama

# %%
average_arrivals_per_month_by_hotel = (
    dataset.groupby(["hotel_id", "arrival_month"])
    .size()
    .reset_index(name="Count")
    .groupby(["hotel_id", "arrival_month"])["Count"]
    .mean()
)
average_arrivals_df = average_arrivals_per_month_by_hotel.reset_index(
    name="Average Arrivals"
)

# %%
print(average_arrivals_df)
# Out:
#     hotel_id  arrival_month  Average Arrivals
# 0          0              1            2191.0
# 1          0              2            3102.0
# 2          0              3            3334.0
# 3          0              4            3609.0
# 4          0              5            3559.0
# 5          0              6            3044.0
# 6          0              7            4573.0
# 7          0              8            4894.0
# 8          0              9            3108.0
# 9          0             10            3553.0
# 10         0             11            2435.0
# 11         0             12            2645.0
# 12         1              1            7276.0
# 13         1              2            4950.0
# 14         1              3            2221.0
# 15         1              4            2544.0
# 16         1              5            4574.0
# 17         1              6            6933.0
# 18         1              7            6967.0
# 19         1              8            6334.0
# 20         1              9            7392.0
# 21         1             10            8792.0
# 22         1             11            7548.0
# 23         1             12           13632.0

# %%
for _, row in anomalie_months_df.iterrows():
    hotel_id = row["Hotel ID"]
    year = row["Year"]
    month = row["Month"]

    average_arrival = average_arrivals_df.loc[
        (average_arrivals_df["hotel_id"] == hotel_id)
        & (average_arrivals_df["arrival_month"] == month),
        "Average Arrivals",
    ].values[0]

    if (
        month in arrival_count.columns
    ):  # Check if the month is a column in the DataFrame
        arrival_count.loc[(hotel_id, year), month] = average_arrival

# %%
print(arrival_count)
# Out:
# arrival_month            1     2     3     4     5     6     7     8     9   \
# hotel_id arrival_year
# 0        2015          2191  3102  3334  3609  3559  3044  1378  1409  1585
#          2016           884  1519  1778  1867  1802  1369  1441  1685  1523
#          2017          1307  1583  1556  1742  1757  1675  1754  1800  3108
# 1        2015           187  4950  2221  2544  1075  6933   768  1392  3524
#          2016          3110  2365  1057  1227  1983  3403  2848  2486  3868
#          2017          3979  2585  1164  1317  1516  3530  3351  2456  7392
#
# arrival_month            10    11    12
# hotel_id arrival_year
# 0        2015          1569  1104  1264
#          2016          1984  1331  1381
#          2017          3553  2435  2645
# 1        2015          2196  1759  2757
#          2016          4272  4274  7166
#          2017          2324  1515  3709

# %%
arrivals_percentage = (
    arrival_count.div(arrival_count.sum(axis=1), axis=0).fillna(0) * 100
)

# %%
fig, axs = plt.subplots(
    num_years,
    num_hotels,
    figsize=(5 * num_hotels, 5 * num_years),
    sharex="col",
    sharey="row",
)

for i, year in enumerate(unique_years):
    for j, hotel_id in enumerate(unique_hotels):
        if num_years == 1 or num_hotels == 1:
            ax = axs[max(i, j)]
        else:
            ax = axs[i, j]

        data = arrivals_percentage.xs(
            (hotel_id, year), level=("hotel_id", "arrival_year")
        ).T

        ax.bar(data.index, data.values.flatten(), color="skyblue")
        ax.set_title(f"Hotel {hotel_id}, {year}")
        ax.set_xticks(range(1, 13))
        ax.set_xticklabels(
            [
                "Jan",
                "Feb",
                "Mar",
                "Apr",
                "May",
                "Jun",
                "Jul",
                "Aug",
                "Sep",
                "Oct",
                "Nov",
                "Dec",
            ]
        )
        if j == 0:
            ax.set_ylabel("Percentage of Arrivals (%)")

plt.tight_layout()
plt.show()

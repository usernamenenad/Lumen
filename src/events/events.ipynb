# %%
import pandas as pd

df = pd.read_json("events.json")
df.head(10)
# Out:
#     country                                              name  \
# 0  [HR, SI]                                             Uskrs
# 1  [HR, SI]                                             Božić
# 2        HR                                  Dani Svetog Vida
# 3        HR                               Riječke ljetne noći
# 4        HR                                  Riječki karneval
# 5        HR                                     Rijeka Advent
# 6        HR                             CEZ Moto Championship
# 7        HR  Alpe Adria International Motorcycle Championship
# 8        HR                                  Ljeto na Gradini
# 9        HR                                         Jazz time
#
#                                                 type location  \
# 0                                 [cultural holiday]     None
# 1                                 [cultural holiday]     None
# 2                                 [cultural holiday]   Rijeka
# ...

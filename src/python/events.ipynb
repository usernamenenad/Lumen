# %%
import pandas as pd

df = pd.read_json("../json/events.json")
df.head(10)
# Out:
#     country                           name  \
# 0  [HR, SI]                          Uskrs
# 1  [HR, SI]                          Božić
# 2        HR              In Music Festival
# 3        HR               Hideout Festival
# 4        HR          Ultra Europe Festival
# 5        HR  Croatia Summer Salsa Festival
# 6        HR             Seasplash Festival
# 7        HR               Dani Svetog Vida
# 8        HR            Riječke ljetne noći
# 9        HR               Riječki karneval
#
#                                                 type location  \
# 0                                 [cultural holiday]     None
# 1                                 [cultural holiday]     None
# 2                                   [music festival]   Zagreb
# 3                                   [music festival]      Pag
# 4                                   [music festival]    Split
# 5                   [dance festival, music festival]   Rovinj
# ...

# %%
import pandas as pd

df = pd.read_json("../json/events.json")
df.head(10)
# Out:
#   country                           name                                 type  \
# 0      HR                          Uskrs                   [cultural holiday]
# 1      SI                          Uskrs                   [cultural holiday]
# 2      HR                          Božić                   [cultural holiday]
# 3      SI                          Božić                   [cultural holiday]
# 4      HR              In Music Festival                     [music festival]
# 5      HR               Hideout Festival                     [music festival]
# 6      HR          Ultra Europe Festival                     [music festival]
# 7      HR  Croatia Summer Salsa Festival                     [music festival]
# 8      HR             Seasplash Festival                     [music festival]
# 9      HR                        Vidfest  [music festival, cultural festival]
#
#   location                 time  \
# 0     None       [march, april]
# 1     None       [march, april]
# ...
